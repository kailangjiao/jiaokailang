# %%
import gym
env = gym.make('CartPole-v0')
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)   #下一步
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# [ 0.00986931  0.02947828 -0.04538988  0.00474455]
# [ 0.01045888 -0.16496431 -0.04529499  0.282768  ]
# [ 0.00715959 -0.35941192 -0.03963963  0.56082809]
# [-2.86445399e-05 -5.53955778e-01 -2.84230648e-02  8.40763645e-01]
# [-0.01110776 -0.74867841 -0.01160779  1.12437436]
# [-0.02608133 -0.9436463   0.0108797   1.41339388]
# [-0.04495425 -1.13890137  0.03914757  1.70945773]
# [-0.06773228 -0.94425052  0.07333673  1.42921159]
# [-0.08661729 -0.75010681  0.10192096  1.16032047]
# [-0.10161943 -0.55644949  0.12512737  0.90125487]
# [-0.11274842 -0.36322469  0.14315247  0.6503752 ]
# [-0.12001291 -0.17035618  0.15615997  0.40597489]
# [-0.12342004  0.02224657  0.16427947  0.16631088]
# [-0.1229751  -0.1747992   0.16760569  0.50598134]
# [-0.12647109 -0.3718372   0.17772531  0.84644239]
# [-0.13390783 -0.17952698  0.19465416  0.61449747]
# [-0.13749837  0.01241911  0.20694411  0.3888834 ]
# Episode finished after 17 timesteps
# [-0.04236002  0.0320055  -0.01264384 -0.00979546]
# ...
